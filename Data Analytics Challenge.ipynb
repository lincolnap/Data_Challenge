# %%
# !pip install tweepy

# %%
import tweepy
import json
import pandas
#Importacion de codigos
consumer_key = "OI6QZVpLLsbrJ4kcD4mYQ1886"
consumer_secret = "suWmOpMRYjT3IlGYVV39eFaLd1YN4l1qGTsqRRkJwjgvoEy6q6"
access_token = "169307294-uXAsrwD9Qac6yxA8cWmqFc3fzJTLdlDUH4M2u20R"
access_token_secret = "jhDMSWMTMv1dEcdjropBpSA7Ixeve9IjQRSvoxdLL1UB2"

# %%
#Envio de credenciales para obtencion de datos Autenticacion OAuth-1
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

# %%
#Variable para busqueda
seach = "Panama"

# %%
#Obtencion de 1000 Tweet relevantes a panama
for busqueda in tweepy.Cursor(api.search, q=seach, Tweet_mode="extended").items(1000):
   x =(json.dumps(busqueda._json["text"], indent=4))
   print(x)
# Out:
# "Narcos desaf\u00edan los huracanes en Panam\u00e1 para tratar de mover su droga https://t.co/3MKM0nKhdS https://t.co/HSJBgTQjxn"
# "Leyes no han frenado la crueldad contra los animales dom\u00e9sticos en Panam\u00e1 https://t.co/Y1lbhCDJnZ https://t.co/koEOMEg5P2"
# "Messi woke up feeling DANGEROUS vs Peru \ud83e\udd76\ud83e\udd76\n\n- 0 goals \ud83d\ude08\ud83d\ude08\n- 0 assists \ud83d\ude31\ud83d\ude31\n- 0key passes \ud83d\udc10\ud83d\udc10\n- 0 chances created \ud83d\ude33\ud83d\ude33\n-\u00a01\u2026 https://t.co/X3k9XXeFue"
# "RT @Rob_Kimbell: Oops...\n\nhttps://t.co/pxNaxACiO3"
# "Be Strong Central America..........\ud83c\uddf8\ud83c\uddfb\ud83c\uddec\ud83c\uddf9\ud83c\uddf3\ud83c\uddee\ud83c\udded\ud83c\uddf3\ud83c\uddf5\ud83c\udde6\ud83c\udde7\ud83c\uddff\n#InGodWeTrust #TogetherJuntos #PrayForCentralAmerica  #ElSalvador\u2026 https://t.co/1x7AfFxI0I"
# ...
